# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import netCDF4
import requests
from datetime import date, timedelta
import xarray as xr

start_date = date(1990,1,1) 
end_date = date(2021,1,1)
delta = end_date-start_date

days = []
for i in range(delta.days + 1):
    day = start_date + timedelta(days=i)

    day = start_date + timedelta(days=0)
    
# file = f"https://www.star.nesdis.noaa.gov/pub/sod/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/ssta/{day.strftime('%Y')}/ct5km_ssta_v3.1_{day.strftime('%Y')}{day.strftime('%m')}{day.strftime('%d')}.nc"
# open(f"SSTA_data/ssta_{day.strftime('%Y')}{day.strftime('%m')}{day.strftime('%d')}.nc", "wb").write(requests.get(file).content)

ds = netCDF4.Dataset(f"SSTA_data/ssta_{day.strftime('%Y')}{day.strftime('%m')}{day.strftime('%d')}.nc")
time = np.array(ds.variables['time'])
lat = np.array(ds.variables['lat'])
lon = np.array(ds.variables['lon'])
sea_surface_temperature_anomaly = np.array(ds.variables['sea_surface_temperature_anomaly'])

# %%
xr_ssta = xr.DataArray(sea_surface_temperature_anomaly,coords=[time,lat,lon],dims=['time','lat','long'])

# %%
xr_ssta
# Out:
# <xarray.DataArray (time: 1, lat: 3600, long: 7200)>
# array([[[-32768., -32768., -32768., ..., -32768., -32768., -32768.],
#         [-32768., -32768., -32768., ..., -32768., -32768., -32768.],
#         [-32768., -32768., -32768., ..., -32768., -32768., -32768.],
#         ...,
#         [-32768., -32768., -32768., ..., -32768., -32768., -32768.],
#         [-32768., -32768., -32768., ..., -32768., -32768., -32768.],
#         [-32768., -32768., -32768., ..., -32768., -32768., -32768.]]])
# Coordinates:
#   * time     (time) int32 284040000
#   * lat      (lat) float32 89.97 89.93 89.88 89.82 ... -89.88 -89.93 -89.97
#   * long     (long) float32 -180.0 -179.9 -179.9 -179.8 ... 179.9 179.9 180.0

# %%
file = 'https://www.ncei.noaa.gov/thredds-ocean/fileServer/cortad/Version4/cortadv4_row00_col00.nc'

# %%
# file = f"https://www.star.nesdis.noaa.gov/pub/sod/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/ssta/{day.strftime('%Y')}/ct5km_ssta_v3.1_{day.strftime('%Y')}{day.strftime('%m')}{day.strftime('%d')}.nc"
open('sst_test.nc', "wb").write(requests.get(file).content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       1 # file = f"https://www.star.nesdis.noaa.gov/pub/sod/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/ssta/{day.strftime('%Y')}/ct5km_ssta_v3.1_{day.strftime('%Y')}{day.strftime('%m')}{day.strftime('%d')}.nc"
# ----> 2 open('sst_test.nc', "wb").write(requests.get(file).content)
#
# File ~\AppData\Local\miniforge3\envs\pac_model\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
start_time = perf_counter()

# create and start threads
threads = []
for day in days:
    
    file = f"https://www.star.nesdis.noaa.gov/pub/sod/mecb/crw/data/5km/v3.1_op/nc/v1.0/daily/ssta/{day.strftime('%Y')}/ct5km_ssta_v3.1_{day.strftime('%Y')}{day.strftime('%m')}{day.strftime('%d')}.nc"
    
    t = Thread(target=task, args=(file,))
    
    sleep(10)
    threads.append(t)
    t.start()

# wait for the threads to complete
for t in threads:
    t.join()

end_time = perf_counter()
